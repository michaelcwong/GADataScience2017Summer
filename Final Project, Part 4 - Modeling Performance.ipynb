# %%
# Import necessary packages for analysis
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Set file name to load, containing the data to be analyzed
file_name = r"C:\Users\michael.wong\Desktop\GADataScience\Final Project\usa_00008.dat"

# The data set used in this analysis was limited to 2015, due to the large file size across multiple years. 
# It is assumed the range of values is similar across years of the surveys.

# %%
# The file is downloaded in fixed width format
# The specifications provide the start and end position for each variable and the variable name
colspecs = [(0,4),(4,6),(6,14),(14,16),(16,26),(26,28),(28,30),(30,34),(34,37),(37,41),(41,46),(46,50),(50,51),
            (51,55),(55,59),(59,66),(66,73),(73,74),(74,76),(76,77),(77,78),(78,79),(79,80),(80,81),(81,82),
            (82,86),(86,96),(96,97),(97,100),(100,102),(102,105),(105,106),(106,108),(108,109),(109,113),(113,116)]
names = ['YEAR','DATANUM','SERIAL','NUMPREC','HHWT','STATEICP','STATEFIP','COUNTY','COUNTYFIPS','CITY',
         'PUMA','CPUMA0010','GQ','RENT','RENTGRS','HHINCOME','VALUEH','VACANCY','UNITSSTR','QRENT','QRENTGRS',
         'QVALUEH','QVACANCY','QUNITSST','QHHINCOME','PERNUM','PERWT','RACE','RACED','EDUC','EDUCD','EMPSTAT',
         'EMPSTATD','LABFORCE','OCC2010','IND1990']

# Some extra variables, in addition to those intended for analysis have been included in case they may be useful later

# %%
data = pd.read_fwf(file_name, header=None, colspecs=colspecs, names=names)

# %%
# Select columns of interest for analysis
data_primary=data[['VALUEH','RENT','HHINCOME','UNITSSTR','EDUC','RACE','EMPSTAT','PUMA']]

# %%
# take brooklyn data only, for speed/scope
brooklyn = data_primary[data_primary['PUMA'].isin([4001,4004,4003,4002,4008,4005,4012,4006,4011,4013,4017,4014,4018,4015,
                                                   4016,4007,4010,4009])]

# %%
pd.set_option('display.max_columns', None)

# %%
# replace default values that skew data
brooklyn.VALUEH = brooklyn.VALUEH.replace({9999999.0: np.nan})
brooklyn.HHINCOME = brooklyn.HHINCOME.replace({9999999.0: np.nan})
# Out:
# C:\ProgramData\Anaconda2\lib\site-packages\pandas\core\generic.py:2999: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value

# %%
brooklyn = brooklyn.dropna()

# %%
# Apply the hist and show functions to plot and show histograms of the 4 columns of data
brooklyn.hist();
plt.show();

# %%
brooklyn.describe()
# Out:
#              VALUEH     RENT      HHINCOME      UNITSSTR          EDUC  \
# count  16972.000000  16972.0  16972.000000  16972.000000  16972.000000
# mean       0.566672      0.0      0.122939      4.215590      6.329661
# std        0.705234      0.0      0.122285      1.842258      3.424743
# min        0.001000      0.0     -0.002700      1.000000      0.000000
# 25%        0.180000      0.0      0.052000      3.000000      4.000000
# 50%        0.400000      0.0      0.093500      3.000000      6.000000
# 75%        0.700000      0.0      0.150663      5.000000     10.000000
# max        4.856000      0.0      1.481000     10.000000     11.000000
#
#                RACE       EMPSTAT          PUMA        EDUC_1        EDUC_2  \
# count  16972.000000  16972.000000  16972.000000  16972.000000  16972.000000
# mean       2.005362      1.472602   4007.542187      0.084021      0.071647
# std        1.769069      1.116624      5.433789      0.277427      0.257911
# ...

# %%
brooklyn[['VALUEH']]=np.divide(brooklyn[['VALUEH']], 1000000)

# %%
brooklyn[['HHINCOME']]=np.divide(brooklyn[['HHINCOME']], 1000000)

# %%
correlations = bro.corr()

# %%
print correlations
# Out:
#             VALUEH  RENT  HHINCOME  UNITSSTR      EDUC      RACE   EMPSTAT  \
# VALUEH    1.000000   NaN  0.364049  0.206917  0.028713  0.001631 -0.021661
# RENT           NaN   NaN       NaN       NaN       NaN       NaN       NaN
# HHINCOME  0.364049   NaN  1.000000  0.088019  0.100062 -0.047327 -0.164141
# UNITSSTR  0.206917   NaN  0.088019  1.000000  0.063524  0.059128 -0.003444
# EDUC      0.028713   NaN  0.100062  0.063524  1.000000 -0.100593  0.295330
# RACE      0.001631   NaN -0.047327  0.059128 -0.100593  1.000000 -0.047608
# EMPSTAT  -0.021661   NaN -0.164141 -0.003444  0.295330 -0.047608  1.000000
# PUMA      0.222733   NaN -0.000309  0.309924 -0.044226  0.106987  0.040255
#
#               PUMA
# VALUEH    0.222733
# RENT           NaN
# HHINCOME -0.000309
# UNITSSTR  0.309924
# EDUC     -0.044226
# RACE      0.106987
# EMPSTAT   0.040255
# PUMA      1.000000

# %%
bk_dummies = pd.get_dummies(brooklyn.EDUC,prefix='EDUC',drop_first=True)
brooklyn = pd.concat([brooklyn,bk_dummies],axis=1)

# %%
bk_dummies = pd.get_dummies(brooklyn.UNITSSTR,prefix='UNITSSTR',drop_first=True)
brooklyn = pd.concat([brooklyn,bk_dummies],axis=1)

# %%
bk_dummies = pd.get_dummies(brooklyn.RACE,prefix='RACE',drop_first=True)
brooklyn = pd.concat([brooklyn,bk_dummies],axis=1)

# %%
bk_dummies = pd.get_dummies(brooklyn.EMPSTAT,prefix='EMPSTAT',drop_first=True)
brooklyn = pd.concat([brooklyn,bk_dummies],axis=1)

# %%
bk_dummies = pd.get_dummies(brooklyn.PUMA,prefix='PUMA',drop_first=True)
brooklyn = pd.concat([brooklyn,bk_dummies],axis=1)

# %%
brooklyn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16972 entries, 825234 to 2481545
# Data columns (total 55 columns):
# VALUEH         16972 non-null float64
# RENT           16972 non-null int64
# HHINCOME       16972 non-null float64
# UNITSSTR       16972 non-null int64
# EDUC           16972 non-null int64
# RACE           16972 non-null int64
# EMPSTAT        16972 non-null int64
# PUMA           16972 non-null int64
# EDUC_1         16972 non-null uint8
# EDUC_2         16972 non-null uint8
# EDUC_3         16972 non-null uint8
# EDUC_4         16972 non-null uint8
# EDUC_5         16972 non-null uint8
# EDUC_6         16972 non-null uint8
# EDUC_7         16972 non-null uint8
# EDUC_8         16972 non-null uint8
# EDUC_10        16972 non-null uint8
# EDUC_11        16972 non-null uint8
# UNITSSTR_2     16972 non-null uint8
# UNITSSTR_3     16972 non-null uint8
# UNITSSTR_4     16972 non-null uint8
# UNITSSTR_5     16972 non-null uint8
# UNITSSTR_6     16972 non-null uint8
# ...

# %%
import statsmodels.formula.api as smf
lm_stats = smf.ols(formula='VALUEH ~ HHINCOME +PUMA_4002+PUMA_4003+PUMA_4004+PUMA_4005+PUMA_4006+PUMA_4007+PUMA_4008+PUMA_4009+PUMA_4010+PUMA_4011+PUMA_4012+PUMA_4013+PUMA_4014+PUMA_4015+PUMA_4016+PUMA_4017+PUMA_4018+RACE_4+EMPSTAT_1+UNITSSTR_3+UNITSSTR_4+UNITSSTR_5+UNITSSTR_6+UNITSSTR_7+UNITSSTR_8+UNITSSTR_9+UNITSSTR_10', data=brooklyn).fit()
lm_stats.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 VALUEH   R-squared:                       0.267
# Model:                            OLS   Adj. R-squared:                  0.266
# Method:                 Least Squares   F-statistic:                     220.6
# Date:                Thu, 28 Sep 2017   Prob (F-statistic):               0.00
# Time:                        22:09:37   Log-Likelihood:                -15517.
# No. Observations:               16972   AIC:                         3.109e+04
# Df Residuals:                   16943   BIC:                         3.132e+04
# Df Model:                          28
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept       0.0166      0.039      0.428      0.669      -0.059       0.093
# ...

# %%
from sklearn import cross_validation

# %%
from sklearn import linear_model, metrics

# %%
brooklyn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16972 entries, 825234 to 2481545
# Data columns (total 55 columns):
# VALUEH         16972 non-null float64
# RENT           16972 non-null int64
# HHINCOME       16972 non-null float64
# UNITSSTR       16972 non-null int64
# EDUC           16972 non-null int64
# RACE           16972 non-null int64
# EMPSTAT        16972 non-null int64
# PUMA           16972 non-null int64
# EDUC_1         16972 non-null uint8
# EDUC_2         16972 non-null uint8
# EDUC_3         16972 non-null uint8
# EDUC_4         16972 non-null uint8
# EDUC_5         16972 non-null uint8
# EDUC_6         16972 non-null uint8
# EDUC_7         16972 non-null uint8
# EDUC_8         16972 non-null uint8
# EDUC_10        16972 non-null uint8
# EDUC_11        16972 non-null uint8
# UNITSSTR_2     16972 non-null uint8
# UNITSSTR_3     16972 non-null uint8
# UNITSSTR_4     16972 non-null uint8
# UNITSSTR_5     16972 non-null uint8
# UNITSSTR_6     16972 non-null uint8
# ...

# %%
modeldata = brooklyn[['HHINCOME','EDUC_1','EDUC_2','EDUC_3','EDUC_4','EDUC_5',
                      'EDUC_6','EDUC_7','EDUC_8','EDUC_10','EDUC_11',
                      'UNITSSTR_2','UNITSSTR_3','UNITSSTR_4','UNITSSTR_5','UNITSSTR_6',
                      'UNITSSTR_7','UNITSSTR_8','UNITSSTR_9','UNITSSTR_10','RACE_2','RACE_3',
                      'RACE_4','RACE_5','RACE_6','RACE_7','RACE_8','RACE_9','EMPSTAT_1',
                      'EMPSTAT_2','EMPSTAT_3',]]
y = brooklyn.VALUEH

scores = []
kf = cross_validation.KFold(len(modeldata), n_folds=10, shuffle=True)
for train_index, test_index in kf:
    lm = linear_model.LinearRegression().fit(
        modeldata.iloc[train_index], y.iloc[train_index])
    scores.append(metrics.mean_squared_error(
        y.iloc[test_index], lm.predict(modeldata.iloc[test_index])))

print(scores)
np.mean(scores)
# Out:
# [0.41852374164521128, 0.38907020335669623, 0.43000572478753507, 0.37432297079233401, 0.41767387544404572, 0.35865915678309751, 0.37727054967234974, 0.35907814680707395, 0.31726061335021077, 0.42438722296380249]
# 0.38662522056023568

# %%
mse_avg = {}
for n_folds in range(3, 100, 2):
    mse_values = []
    scores = []
    n= 0

    scores = []
    kf = cross_validation.KFold(len(modeldata), n_folds=n_folds, shuffle=True)
    for train_index, test_index in kf:
        lm = linear_model.LinearRegression().fit(
            modeldata.iloc[train_index], y.iloc[train_index])
        mse_values.append(metrics.mean_squared_error(
            y.iloc[test_index], lm.predict(modeldata.iloc[test_index])))
        scores.append(lm.score(modeldata, y))
        n+=1

        mse_avg[n_folds] = np.mean(mse_values)
    print 'Mean of MSE for {} folds:'.format(n_folds), np.mean(mse_values)
pd.Series(mse_avg).plot();
plt.show()
# Out:
# Mean of MSE for 3 folds: 0.387610409386
# Mean of MSE for 5 folds: 0.386963528664
# Mean of MSE for 7 folds: 0.386604199602
# Mean of MSE for 9 folds: 0.386678537564
# Mean of MSE for 11 folds: 0.386886646103
# Mean of MSE for 13 folds: 0.386592771696
# Mean of MSE for 15 folds: 0.386728813331
# Mean of MSE for 17 folds: 0.386837365219
# Mean of MSE for 19 folds: 0.386709710753
# Mean of MSE for 21 folds: 0.386480151293
# Mean of MSE for 23 folds: 0.386676319786
# Mean of MSE for 25 folds: 0.386850287988
# Mean of MSE for 27 folds: 0.386642485051
# Mean of MSE for 29 folds: 0.386604568556
# Mean of MSE for 31 folds: 0.386796260869
# Mean of MSE for 33 folds: 0.386695038708
# Mean of MSE for 35 folds: 0.386753749547
# Mean of MSE for 37 folds: 0.386643848534
# Mean of MSE for 39 folds: 0.386733810581
# Mean of MSE for 41 folds: 0.386763422815
# Mean of MSE for 43 folds: 0.386678287031
# Mean of MSE for 45 folds: 0.386543620207
# Mean of MSE for 47 folds: 0.386877358207
# ...

# %%
lm = linear_model.LinearRegression().fit(modeldata, y)
print "~~~~ Single Model ~~~~"
print 'MSE of single model:', metrics.mean_squared_error(y, lm.predict(modeldata))
print 'R2: ', lm.score(modeldata, y)
# Out:
# ~~~~ Single Model ~~~~
# MSE of single model: 0.385178141778
# R2:  0.22550109383

# %%
lm = linear_model.LinearRegression().fit(modeldata, y)
print "~~~ OLS ~~~"
print 'OLS MSE: ', metrics.mean_squared_error(y, lm.predict(modeldata))
print 'OLS R2:', lm.score(modeldata, y)

lm = linear_model.Lasso().fit(modeldata, y)
print "~~~ Lasso ~~~"
print 'Lasso MSE: ', metrics.mean_squared_error(y, lm.predict(modeldata))
print 'Lasso R2:', lm.score(modeldata, y)

lm = linear_model.Ridge().fit(modeldata, y)
print "~~~ Ridge ~~~"
print 'Ridge MSE: ', metrics.mean_squared_error(y, lm.predict(modeldata))
print 'Ridge R2:', lm.score(modeldata, y)
# Out:
# ~~~ OLS ~~~
# OLS MSE:  0.385178141778
# OLS R2: 0.22550109383
# ~~~ Lasso ~~~
# Lasso MSE:  0.497325611063
# Lasso R2: 0.0
# ~~~ Ridge ~~~
# Ridge MSE:  0.385182870341
# Ridge R2: 0.225491585848

# %%
from sklearn.model_selection import GridSearchCV

alphas = np.logspace(-10, 10, 21)
gs = GridSearchCV(
    cv=5,
    estimator=linear_model.Ridge(),
    param_grid={'alpha': alphas, 'fit_intercept': [True, False]},
    scoring='mean_squared_error')

gs.fit(modeldata, y)
# Out:
# C:\ProgramData\Anaconda2\lib\site-packages\sklearn\metrics\scorer.py:90: DeprecationWarning: Scoring method mean_squared_error was renamed to neg_mean_squared_error in version 0.18 and will be removed in 0.20.
#   sample_weight=sample_weight)
# C:\ProgramData\Anaconda2\lib\site-packages\sklearn\metrics\scorer.py:90: DeprecationWarning: Scoring method mean_squared_error was renamed to neg_mean_squared_error in version 0.18 and will be removed in 0.20.
#   sample_weight=sample_weight)
# C:\ProgramData\Anaconda2\lib\site-packages\sklearn\metrics\scorer.py:90: DeprecationWarning: Scoring method mean_squared_error was renamed to neg_mean_squared_error in version 0.18 and will be removed in 0.20.
#   sample_weight=sample_weight)
# C:\ProgramData\Anaconda2\lib\site-packages\sklearn\metrics\scorer.py:90: DeprecationWarning: Scoring method mean_squared_error was renamed to neg_mean_squared_error in version 0.18 and will be removed in 0.20.
#   sample_weight=sample_weight)
# ...

# %%
print -gs.best_score_
# Out:
# 0.399099194204

# %%
print gs.best_estimator_
# Out:
# Ridge(alpha=0.10000000000000001, copy_X=True, fit_intercept=False,
#    max_iter=None, normalize=False, random_state=None, solver='auto',
#    tol=0.001)

# %%
from pprint import pprint
pprint(gs.grid_scores_)
# Out:
# [mean: -0.39943, std: 0.20913, params: {'alpha': 1e-10, 'fit_intercept': True},
#  mean: -0.39910, std: 0.20933, params: {'alpha': 1e-10, 'fit_intercept': False},
#  mean: -0.39943, std: 0.20913, params: {'alpha': 1.0000000000000001e-09, 'fit_intercept': True},
#  mean: -0.39910, std: 0.20933, params: {'alpha': 1.0000000000000001e-09, 'fit_intercept': False},
#  mean: -0.39943, std: 0.20913, params: {'alpha': 1e-08, 'fit_intercept': True},
#  mean: -0.39910, std: 0.20933, params: {'alpha': 1e-08, 'fit_intercept': False},
#  mean: -0.39943, std: 0.20913, params: {'alpha': 9.9999999999999995e-08, 'fit_intercept': True},
#  mean: -0.39910, std: 0.20933, params: {'alpha': 9.9999999999999995e-08, 'fit_intercept': False},
#  mean: -0.39943, std: 0.20913, params: {'alpha': 9.9999999999999995e-07, 'fit_intercept': True},
#  mean: -0.39910, std: 0.20933, params: {'alpha': 9.9999999999999995e-07, 'fit_intercept': False},
# ...

# %%
lm = linear_model.SGDRegressor()
lm.fit(modeldata, y)
print "Gradient Descent R2:", lm.score(modeldata, y)
print "Gradient Descent MSE:", metrics.mean_squared_error(y, lm.predict(modeldata))
# Out:
# Gradient Descent R2: 0.204422022636
# Gradient Descent MSE: 0.395661303741

# %%
alphas = np.logspace(-10, 10, 21)
params = {'alpha': alphas } # put your gradient descent parameters here
gs = GridSearchCV(
    estimator=linear_model.SGDRegressor(),
    cv=cross_validation.KFold(len(modeldata), n_folds=5, shuffle=True),
    param_grid=params,
    scoring='neg_mean_squared_error',
    )

gs.fit(modeldata, y)

print 'BEST ESTIMATOR'
print -gs.best_score_
print gs.best_estimator_
print 'ALL ESTIMATORS'
print gs.grid_scores_
# Out:
# BEST ESTIMATOR
# 0.399204806473
# SGDRegressor(alpha=1.0000000000000001e-09, average=False, epsilon=0.1,
#        eta0=0.01, fit_intercept=True, l1_ratio=0.15,
#        learning_rate='invscaling', loss='squared_loss', n_iter=5,
#        penalty='l2', power_t=0.25, random_state=None, shuffle=True,
#        verbose=0, warm_start=False)
# ALL ESTIMATORS
# ...

# %%
from sklearn.tree import DecisionTreeClassifier, export_graphviz # to visualize decision tree using graphviz http://www.graphviz.org/
from sklearn.externals.six import StringIO
import pydot # python interface to graphviz dot language https://github.com/erocarrera/pydot
from os import system
from IPython.display import Image # to display graphviz image in notebook

# %%
brooklyn['VALUEH'] = brooklyn.VALUEH.astype(int)
brooklyn['HHINCOME'] = brooklyn.HHINCOME.astype(int)
# Instantiating our model object
model = DecisionTreeClassifier(max_depth=5) # Setting depth=2 (to ask only two questions)

# Selecting a few variables for demo
X = brooklyn[['HHINCOME','UNITSSTR','EDUC','RACE','EMPSTAT']] 
y = brooklyn[['VALUEH']]

# Fits the model
model.fit(X, y)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=5,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best')

# %%
brooklyn['intercept']=1.0

# %%
from sklearn.model_selection import cross_val_score
from sklearn.tree import DecisionTreeClassifier, export_graphviz

# Need this set up (from above)
model = DecisionTreeClassifier(max_depth=10)

X = brooklyn[['HHINCOME','UNITSSTR','EDUC','RACE','EMPSTAT','intercept']].dropna() # dropping missing variables
y = brooklyn['VALUEH'] # creating evergreen label from X to account for dropped rows

for depth in range(2, 10):
    model = DecisionTreeClassifier(max_depth=depth)
    scores = cross_val_score(model, X, y, scoring='neg_mean_squared_error', cv=5)
    print(depth, scores.mean())
# Out:
# (2, -0.44066594899762868)
# (3, -0.44726777628911113)
# (4, -0.44726777628911113)
# (5, -0.4483296159381317)
# (6, -0.44968349159345433)
# (7, -0.45174684047965463)
# (8, -0.45404555211533015)
# (9, -0.45716954458160092)

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(n_estimators = 20)
model.fit(X, y)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             n_estimators=20, n_jobs=1, oob_score=False, random_state=None,
#             verbose=0, warm_start=False)

# %%
features = X.columns
feature_importances = model.feature_importances_

features_df = pd.DataFrame({'Features': features, 'Importance Score': feature_importances})
features_df.sort_values('Importance Score', inplace=True, ascending=False)

features_df.head()
# Out:
#    Features  Importance Score
# 1  UNITSSTR          0.411082
# 2      EDUC          0.253449
# 3      RACE          0.227138
# 4   EMPSTAT          0.083653
# 0  HHINCOME          0.024679

# %%
from sklearn.cross_validation import cross_val_score

scores = cross_val_score(model, X, y, scoring='neg_mean_squared_error')
print('MSE {}, mean MSE {}'.format(scores, scores.mean()))

MSE_scores = {}
for n_trees in range(1, 100, 10):
    model = RandomForestClassifier(n_estimators = n_trees)
    scores = cross_val_score(model, X, y, scoring='neg_mean_squared_error')
    print('n trees: {}, MSE {}, mean MSE {}'.format(n_trees, scores, scores.mean()))
    MSE_scores[n_trees] = scores.mean()
pd.Series(MSE_scores, name='MSE Scores').plot();
# Out:
# MSE [-0.47729281 -0.54587237 -0.49098303], mean MSE -0.504716068435
# n trees: 1, MSE [-0.48930907 -0.56690826 -0.49876238], mean MSE -0.518326565567
# n trees: 11, MSE [-0.45750133 -0.57291851 -0.48514851], mean MSE -0.505189449406
# n trees: 21, MSE [-0.45750133 -0.57786813 -0.48055163], mean MSE -0.505307026632
# n trees: 31, MSE [-0.45626436 -0.52289199 -0.48214286], mean MSE -0.487099735675
# n trees: 41, MSE [-0.4552041  -0.53880148 -0.48355728], mean MSE -0.492520956283
# n trees: 51, MSE [-0.45732462 -0.55152908 -0.48037482], mean MSE -0.496409505957
# n trees: 61, MSE [-0.45538081 -0.53137705 -0.48055163], mean MSE -0.489103163633
# n trees: 71, MSE [-0.4569712  -0.55400389 -0.47666195], mean MSE -0.495879012407
# n trees: 81, MSE [-0.45573423 -0.52642744 -0.48550212], mean MSE -0.48922126178
# n trees: 91, MSE [-0.45820816 -0.52625066 -0.48479491], mean MSE -0.489751244981

# %%
plt.show()
